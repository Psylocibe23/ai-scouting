# %% [markdown]
# <a href="https://colab.research.google.com/github/Psylocibe23/ai-scouting-paprika/blob/main/analysis/ai_scouting_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import platform

print("Hello from Colab, AI Scouting analysis notebook is live!")
print("Python version:", sys.version)
print("Platform:", platform.platform())
# Out:
# Hello from Colab, AI Scouting analysis notebook is live!
# Python version: 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# Platform: Linux-6.6.105+-x86_64-with-glibc2.35
